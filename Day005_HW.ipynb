# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

import json
data = json.loads(r.text)
print(data)
print(len(data))
# Out:
# [{'id': 233303550, 'title': '跟哥哥姐姐說你賣什麼', 'excerpt': '來！跟哥哥姐姐說你賣什麼？路易：哥哥姊姊我賣萌 🥺，那老爸賣什麼 ？賣醜照🤪，啊，錯棚 🤣 （路易的老哥），再來一個路易招牌饋頭🤣，路易的生活日記，第一次幫路易PO低卡 希望大家能捧個場 🥺', 'anonymousSchool': False, 'anonymousDepartment': False, 'pinned': False, 'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49', 'replyId': None, 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z', 'commentCount': 16, 'likeCount': 363, 'withNickname': True, 'tags': [], 'topics': ['貓', '寵物', '可愛', '貓咪', '橘貓'], 'meta': {'layout': 'classic'}, 'forumName': '寵物', 'forumAlias': 'pet', 'gender': 'M', 'school': '路易老爸 ', 'department': 'zxcsd75319', 'replyTitle': None, 'mediaMeta': [{'id': '79cf5f52-6c6f-4071-86c7-67f6c93618bd', 'url': 'https://i.imgur.com/OlQMaVyl.jpg', 'normalizedUrl': 'https://i.imgur.com/OlQMaVyl.jpg', 'thumbnail': 'https://i.imgur.com/OlQMaVyl.jpg', 'type': 'image/thumbnail', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '79cf5f52-6c6f-4071-86c7-67f6c93618bd', 'url': 'https://i.imgur.com/OlQMaVy.jpg', 'normalizedUrl': 'https://imgur.com/OlQMaVy', 'thumbnail': 'https://i.imgur.com/OlQMaVyl.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '7a3cd6e6-b653-48ad-aafd-4eeba96670e7', 'url': 'https://i.imgur.com/NfIPjO4.jpg', 'normalizedUrl': 'https://imgur.com/NfIPjO4', 'thumbnail': 'https://i.imgur.com/NfIPjO4l.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '638c14c8-25d2-4314-ab95-510553daf8ee', 'url': 'https://i.imgur.com/s66YPm6.jpg', 'normalizedUrl': 'https://imgur.com/s66YPm6', 'thumbnail': 'https://i.imgur.com/s66YPm6l.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '85329f27-c0b8-4502-9d91-6072abc28f9c', 'url': 'https://i.imgur.com/pi3hGOs.jpg', 'normalizedUrl': 'https://imgur.com/pi3hGOs', 'thumbnail': 'https://i.imgur.com/pi3hGOsl.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '02cf1d76-e11a-410a-a44e-f35a01b694ce', 'url': 'https://i.imgur.com/A0r9PKV.jpg', 'normalizedUrl': 'https://imgur.com/A0r9PKV', 'thumbnail': 'https://i.imgur.com/A0r9PKVl.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '88c96f02-1243-4e54-821b-b268e2e74881', 'url': 'https://i.imgur.com/p18NVTd.jpg', 'normalizedUrl': 'https://imgur.com/p18NVTd', 'thumbnail': 'https://i.imgur.com/p18NVTdl.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '500b64bd-dc47-4f41-aadb-1590be63a803', 'url': 'https://i.imgur.com/NSagiPq.jpg', 'normalizedUrl': 'https://imgur.com/NSagiPq', 'thumbnail': 'https://i.imgur.com/NSagiPql.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '804b9c72-d2ac-466f-a223-0e405cac3b04', 'url': 'https://i.imgur.com/UT8eunc.jpg', 'normalizedUrl': 'https://imgur.com/UT8eunc', 'thumbnail': 'https://i.imgur.com/UT8euncl.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': '3b1adafa-c65a-48da-969c-1f62d13c1ec2', 'url': 'https://i.imgur.com/u2v7tgc.jpg', 'normalizedUrl': 'https://imgur.com/u2v7tgc', 'thumbnail': 'https://i.imgur.com/u2v7tgcl.jpg', 'type': 'image/imgur', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-20T07:35:32.182Z', 'updatedAt': '2020-03-20T07:35:32.182Z'}, {'id': 'd3ddbd87-20a7-4d51-9720-c20d46fa63d9', 'url': 'https://i.imgur.com/bjwnfYZ.jpg', 'normalizedUrl': 'https://imgur.com/bjwnfYZ', 'thumbnail': 'https://i.imgur.com/bjwnfYZl.jpg', 'type': 'image/imgu ...
# 30

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for i in data:
    print(i['title'])
    print(i['createdAt'])
    print(i['commentCount'])
    print(i['likeCount'])
# Out:
# 跟哥哥姐姐說你賣什麼
# 2020-03-20T07:35:32.182Z
# 16
# 363
# 手手呢ಠ_ಠ
# 2020-03-20T00:20:42.777Z
# 11
# 148
# 當有了一隻像貴婦的狗
# 2020-03-19T21:48:22.044Z
# 6
# 49
# 我家的新成員
# 2020-03-20T07:07:06.758Z
# 2
# 21
# 你的頭怎麼卡住了🤣
# 2020-03-20T03:23:03.621Z
# 11
# 21
# 蝦蝦又來了🤪
# 2020-03-20T15:42:06.600Z
# 3
# 19
# 睡之狂魔
# 2020-03-20T10:18:11.880Z
# 0
# 18
# 超燒！寵物全透明背包開箱🐱
# 2020-03-20T13:57:41.800Z
# 8
# 17
# 是隻熊還是隻狗🐶
# 2020-03-20T10:16:47.745Z
# 4
# 14
# 花橘子
# 2020-03-20T23:38:59.959Z
# 0
# 13
# #貓 #圖 喵的死亡角度
# 2020-03-20T17:02:52.402Z
# 0
# 13
# 狗狗走失協尋 高雄凹子底站
# 2020-03-20T14:59:33.054Z
# 1
# 12
# 我會怕狗
# 2020-03-20T11:50:59.728Z
# 6
# 11
# 蛋頭貓貼圖真貓版ฅ(^•ω •^)ฅ
# 2020-03-20T07:27:49.953Z
# 2
# 9
# 好摸好擼的貓兒子
# 2020-03-20T02:49:52.487Z
# 4
# 8
# 貓奴的夢想？
# 2020-03-20T07:09:48.026Z
# 2
# 7
# 我家狐狸狗常常會露出很人性化表情
# 2020-03-21T01:20:59.246Z
# 0
# 6
# 我們永遠愛你。
# 2020-03-20T16:21:22.491Z
# 1
# 6
# 你好煩喔
# 2020-03-20T08:21:37.253Z
# 1
# 6
# 再頂一次
# 2020-03-20T15:54:23.975Z
# 2
# 5
# 鸚鵡挑食
# 2020-03-20T08:45:23.837Z
# 6
# 5
# 帶狗散步不用牽繩
# 2020-03-20T01:32:19.889Z
# 3
# 5
# 關於鼠鼠結紮
# 2020-03-21T03:29:30.272Z
# 0
# 4
# 求領養認養
# 2020-03-21T03:46:01.351Z
# 0
# 3
# 雖然你很胖...
# 2020-03-20T05:17:20.410Z
# 2
# 3
# 跟店狗互動沒有反應ಥ_ಥ
# 2020-03-21T04:45:00.081Z
# 2
# 2
# 亮片衣服的崩壞
# 2020-03-21T04:04:55.130Z
# 0
# 2
# 養了兩個多月的幼犬護窩
# 2020-03-21T03:40:17.588Z
# 0
# 2
# 第一次設水草缸~~~~
# 2020-03-21T02:22:58.347Z
# 4
# 2
# 最會等的狗👍
# 2020-03-20T12:18:19.553Z
# 0
# 2

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
comment = 0
like = 0
for i in data:
    comment+=i['commentCount']
    like+=i['likeCount']
print(comment/len(data),like/len(data))

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
response = r.text
data = json.loads(r.text)
comment = 0
like = 0
for i in data:
    comment+=i['commentCount']
    like+=i['likeCount']
print(comment/len(data),like/len(data))
# Out:
# 3.2333333333333334 26.533333333333335
# 1.9666666666666666 5.333333333333333
